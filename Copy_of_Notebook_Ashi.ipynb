# %% [markdown]
# <a href="https://colab.research.google.com/github/DiliniSew/Deep-Learning_Mini-Project/blob/Aashi/Copy_of_Notebook_Ashi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Loading

# %%
# !pip install opendatasets
# Out:
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from opendatasets) (4.67.3)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (from opendatasets) (2.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from opendatasets) (8.3.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (6.3.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (0.1.18)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (26.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (5.29.6)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2.32.4)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->kaggle->opendatasets) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle->opendatasets) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle->opendatasets) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle->opendatasets) (2026.2.25)
# Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22

# %%
from keras.preprocessing.image import load_img
import opendatasets as od
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns

import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img
from sklearn.model_selection import train_test_split
from tensorflow.keras.initializers import random_uniform, glorot_uniform, constant, identity
from tensorflow.keras.layers import Dropout, Input, Add, Dense, Activation, BatchNormalization, Flatten, Conv2D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.models import Model, load_model

# %%
od.download("https://www.kaggle.com/datasets/jangedoo/utkface-new?datasetId=44109")
#{"username":"rpddsewwandi","key":"d0fb60c60bae0d7a83861a898162a399"}
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: aashinshanaweerakoon
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/jangedoo/utkface-new
# Downloading utkface-new.zip to ./utkface-new
# 100%|██████████| 331M/331M [00:04<00:00, 81.1MB/s]

# %%
# Removed 'import random' as shuffling is no longer required

data_path = "/content/utkface-new/utkface_aligned_cropped/UTKFace"

image_paths = []
age_labels = []
gender_labels = []

if os.path.exists(data_path):
    print(f"Processing files in '{data_path}'...")
    for item in os.listdir(data_path):
        if item.endswith(".jpg") or item.endswith(".png"):
            # Filename format: age_gender_ethnicity_date.jpg.chip.jpg
            parts = item.split('_')
            if len(parts) >= 2:
                try:
                    age = int(parts[0])
                    gender = int(parts[1])
                    image_paths.append(os.path.join(data_path, item))
                    age_labels.append(age)
                    gender_labels.append(gender)
                except ValueError:
                    # Skip files with unparseable age/gender
                    continue

    print(f"Found {len(image_paths)} images.")

    # Create a DataFrame
    data = pd.DataFrame({
        'image': image_paths,
        'age': age_labels,
        'gender': gender_labels
    })

else:
    print(f"Error: Directory '{data_path}' does not exist.")
# Out:
# Processing files in '/content/utkface-new/utkface_aligned_cropped/UTKFace'...
# Found 23708 images.

# %%
print("\nFirst 5 entries of the DataFrame:")
data.head()
# Out:
# First 5 entries of the DataFrame:
#                                                image  age  gender
# 0  /content/utkface-new/utkface_aligned_cropped/U...   24       0
# 1  /content/utkface-new/utkface_aligned_cropped/U...   40       1
# 2  /content/utkface-new/utkface_aligned_cropped/U...   38       1
# 3  /content/utkface-new/utkface_aligned_cropped/U...   58       1
# 4  /content/utkface-new/utkface_aligned_cropped/U...   48       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23708 entries, 0 to 23707
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   image   23708 non-null  object
#  1   age     23708 non-null  int64
#  2   gender  23708 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 555.8+ KB

# %%
sns.histplot(data.age).set(title="Distribution of Age")
# Out:
# [Text(0.5, 1.0, 'Distribution of Age')]

# %%
# Plotting the distribution of 'gender'
sns.histplot(data.gender).set(title="Distribution of Gender")
# Out:
# [Text(0.5, 1.0, 'Distribution of Gender')]

# %% [markdown]
# #Data Preprocessing

# %%
# Create a copy of the original DataFrame
data_shuffled = data.copy()

# Shuffle the copied DataFrame
data_shuffled = data_shuffled.sample(frac=1).reset_index(drop=True)

print("First 5 entries of the shuffled DataFrame:")
print(data_shuffled.head())
# Out:
# First 5 entries of the shuffled DataFrame:
#                                                image  age  gender
# 0  /content/utkface-new/utkface_aligned_cropped/U...   16       1
# 1  /content/utkface-new/utkface_aligned_cropped/U...   12       0
# 2  /content/utkface-new/utkface_aligned_cropped/U...   31       1
# 3  /content/utkface-new/utkface_aligned_cropped/U...   36       0
# 4  /content/utkface-new/utkface_aligned_cropped/U...   45       0

# %%
print("Null values in the shuffled DataFrame:")
print(data_shuffled.isnull().sum())
# Out:
# Null values in the shuffled DataFrame:
# image     0
# age       0
# gender    0
# dtype: int64

# %% [markdown]
# # Data Analysis
# Analyze the 'age' and 'gender' columns in the `data_shuffled` DataFrame to identify and visualize outliers or inconsistencies, specifically by examining the distribution of age, verifying gender values, and checking for unusual age-gender combinations.

# %% [markdown]
# ## Analyze Age Distribution for Outliers

# %%
print("Descriptive statistics for 'age' column:")
print(data_shuffled['age'].describe())

# Create a box plot of the 'age' column to visualize outliers
sns.boxplot(x=data_shuffled['age']).set(title="Box Plot of Age Distribution with Outliers")
# Out:
# Descriptive statistics for 'age' column:
# count    23708.000000
# mean        33.303484
# std         19.886112
# min          1.000000
# 25%         23.000000
# 50%         29.000000
# 75%         45.000000
# max        116.000000
# Name: age, dtype: float64
# [Text(0.5, 1.0, 'Box Plot of Age Distribution with Outliers')]

# %% [markdown]
# ## Check for Inconsistent Gender Values

# %% [markdown]
# To verify that the 'gender' column only contains binary values (0 or 1).

# %%
print("Unique values in 'gender' column:")
print(data_shuffled['gender'].unique())

print("\nValue counts for 'gender' column:")
print(data_shuffled['gender'].value_counts())
# Out:
# Unique values in 'gender' column:
# [1 0]
#
# Value counts for 'gender' column:
# gender
# 0    12391
# 1    11317
# Name: count, dtype: int64

# %% [markdown]
# ## Identify Extreme Age-Gender Combinations
#
# Investigate if there are any data points with age and gender combinations that seem highly improbable or inconsistent (e.g., extreme ages associated with specific gender representations that could indicate data errors).

# %%
print("Descriptive statistics for 'age' grouped by 'gender':")
print(data_shuffled.groupby('gender')['age'].describe())
# Out:
# Descriptive statistics for 'age' grouped by 'gender':
#           count       mean        std  min   25%   50%   75%    max
# gender
# 0       12391.0  35.695666  19.705223  1.0  25.0  34.0  50.0  110.0
# 1       11317.0  30.684280  19.753650  1.0  21.0  26.0  37.0  116.0

# %% [markdown]
# To visually compare the age distributions for each gender and identify potential outliers, create side-by-side box plots of the 'age' column, separated by 'gender'.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='gender', y='age', data=data_shuffled)
plt.title('Age Distribution by Gender with Outliers')
plt.xlabel('Gender (0: Female, 1: Male)')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ## Summary:
#
# The analysis successfully identified and visualized potential outliers and inconsistencies in the 'age' and 'gender' columns.
# *   **Age Distribution:** The 'age' column shows a wide range (1 to 116 years) with a right-skewed distribution, and a maximum age of 116 indicating potential outliers at the upper end.
# *   **Gender Values:** The 'gender' column is consistent, containing only the expected binary values (0 and 1).
# *   **Age-Gender Combinations:** While both gender groups exhibit a wide age range (up to 110 for gender 0 and 116 for gender 1), no immediately impossible or highly inconsistent age-gender combinations were identified.
#
# ### Data Analysis Key Findings
# *   The 'age' column in `data_shuffled` has a mean of 33.30 and a median of 29.00, suggesting a right-skewed distribution.
# *   A wide age range is observed, from a minimum of 1 year to a maximum of 116 years, with the maximum age potentially indicating outliers.
# *   The 'gender' column contains only two unique values: 0 (12,391 occurrences) and 1 (11,317 occurrences), confirming consistency and the absence of unexpected entries.
# *   When grouped by gender, the mean age for gender 0 is approximately 35.7 years (range 1-110), and for gender 1 is approximately 30.7 years (range 1-116).
# *   No impossible age values (e.g., negative ages) or highly improbable age-gender combinations were found in the dataset, although the upper age limits of 110 and 116 are at the very high end of human lifespan.

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.applications import EfficientNetV2S, MobileNetV2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import os

# %%
image_paths, age_labels, gender_labels = [], [], []

for item in os.listdir(data_path):
    if item.endswith(".jpg") or item.endswith(".png"):
        parts = item.split('_')
        if len(parts) >= 2:
            try:
                age = int(parts[0])
                gender = int(parts[1])
                if 1 <= age <= 80 and gender in [0, 1]:  # outlier filter inline
                    image_paths.append(os.path.join(data_path, item))
                    age_labels.append(age)
                    gender_labels.append(gender)
            except ValueError:
                continue

data = pd.DataFrame({'image': image_paths, 'age': age_labels, 'gender': gender_labels})
print(f"Total valid images: {len(data)}")
# Out:
# Total valid images: 23168

# %%
# Shuffle
data = data.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
# Downsample overrepresented ages
max_samples = int(data['age'].value_counts().quantile(0.75))
downsampled = []
for age in data['age'].unique():
    group = data[data['age'] == age]
    downsampled.append(group.sample(n=min(len(group), max_samples), random_state=42))

data_final = pd.concat(downsampled).sample(frac=1, random_state=42).reset_index(drop=True)
print(f"After downsampling: {len(data_final)}")
# Out:
# After downsampling: 16579

# %%
#DISTRIBUTION after downsampling
sns.histplot(data_final.age).set(title="Distribution of Age after Downsampling")
# Out:
# [Text(0.5, 1.0, 'Distribution of Age after Downsampling')]

# %%
# Split — 75% train, 10% val, 15% test
train_df, test_df = train_test_split(data_final, test_size=0.15, random_state=42)
train_df, val_df  = train_test_split(train_df,  test_size=0.12, random_state=42)

print(f"Train: {len(train_df)} | Val: {len(val_df)} | Test: {len(test_df)}")
# Out:
# Train: 12400 | Val: 1692 | Test: 2487

# %%
IMG_SIZE   = 224
BATCH_SIZE = 32
AUTOTUNE   = tf.data.AUTOTUNE

def load_and_preprocess(path, age, gender):
    img = tf.io.read_file(path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0
    return img, {'age_output': age, 'gender_output': gender}

def augment(img, labels):
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_brightness(img, 0.1)
    img = tf.image.random_contrast(img, 0.9, 1.1)
    return img, labels

def make_dataset(df, augment_data=False):
    ds = tf.data.Dataset.from_tensor_slices((
        df['image'].values,
        df['age'].values.astype(np.float32),
        df['gender'].values.astype(np.float32)
    ))
    ds = ds.map(load_and_preprocess, num_parallel_calls=AUTOTUNE)
    if augment_data:
        ds = ds.map(augment, num_parallel_calls=AUTOTUNE)
    return ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)

train_ds = make_dataset(train_df, augment_data=True)
val_ds   = make_dataset(val_df)
test_ds  = make_dataset(test_df)

# %%
def build_model():
    base = MobileNetV2(
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        include_top=False,
        weights='imagenet'
    )
    base.trainable = False  # frozen for Phase 1

    inputs = tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = base(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)

    age_output    = layers.Dense(1, activation='relu',    name='age_output')(x)
    gender_output = layers.Dense(1, activation='sigmoid', name='gender_output')(x)

    return Model(inputs, [age_output, gender_output]), base

model, base_model = build_model()
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mobilenetv2_1.00_2… │ (None, 7, 7,      │  2,257,984 │ input_layer_1[0]… │
# │ (Functional)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ mobilenetv2_1.00… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    327,936 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256)       │      1,024 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_output (Dense)  │ (None, 1)         │        257 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gender_output       │ (None, 1)         │        257 │ dropout[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,587,458 (9.87 MB)
#  Trainable params: 328,962 (1.25 MB)
#  Non-trainable params: 2,258,496 (8.62 MB)

# %%
model.compile(
    optimizer=Adam(1e-3),
    loss={'age_output': 'mse', 'gender_output': 'binary_crossentropy'},
    loss_weights={'age_output': 0.05, 'gender_output': 1.0},
    metrics={'age_output': 'mae', 'gender_output': 'accuracy'}
)

history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=15,
    callbacks=[
        EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2)
    ]
)
# Out:
# Epoch 1/15
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 64s 111ms/step - age_output_loss: 466.9906 - age_output_mae: 16.6374 - gender_output_accuracy: 0.7774 - gender_output_loss: 0.4924 - loss: 23.8546 - val_age_output_loss: 179.2134 - val_age_output_mae: 10.3111 - val_gender_output_accuracy: 0.8091 - val_gender_output_loss: 0.3945 - val_loss: 9.3513 - learning_rate: 0.0010
# Epoch 2/15
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 16s 40ms/step - age_output_loss: 172.9816 - age_output_mae: 10.1280 - gender_output_accuracy: 0.8044 - gender_output_loss: 0.4420 - loss: 9.0863 - val_age_output_loss: 177.0735 - val_age_output_mae: 10.0549 - val_gender_output_accuracy: 0.8327 - val_gender_output_loss: 0.3745 - val_loss: 9.2205 - learning_rate: 0.0010
# Epoch 3/15
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 15s 40ms/step - age_output_loss: 148.3557 - age_output_mae: 9.3818 - gender_output_accuracy: 0.8167 - gender_output_loss: 0.4074 - loss: 7.8232 - val_age_output_loss: 140.7391 - val_age_output_mae: 9.0036 - val_gender_output_accuracy: 0.8274 - val_gender_output_loss: 0.3677 - val_loss: 7.3995 - learning_rate: 0.0010
# Epoch 4/15
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 15s 40ms/step - age_output_loss: 140.8531 - age_output_mae: 9.1403 - gender_output_accuracy: 0.8201 - gender_output_loss: 0.4012 - loss: 7.4413 - val_age_output_loss: 137.2466 - val_age_output_mae: 8.8647 - val_gender_output_accuracy: 0.8381 - val_gender_output_loss: 0.3520 - val_loss: 7.2089 - learning_rate: 0.0010
# Epoch 5/15
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - age_output_loss: 134.9259 - age_output_mae: 8.9393 - gender_output_accuracy: 0.8239 - gender_output_loss: 0.3902 - loss: 7.1372 - val_age_output_loss: 137.1994 - val_age_output_mae: 8.9624 - val_gender_output_accuracy: 0.8528 - val_gender_output_loss: 0.3497 - val_loss: 7.2060 - learning_rate: 0.0010
# Epoch 6/15
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - age_output_loss: 131.9993 - age_output_mae: 8.8410 - gender_output_accuracy: 0.8294 - gender_output_loss: 0.3857 - loss: 6.9837 - val_age_output_loss: 135.7726 - val_age_output_mae: 8.7916 - val_gender_output_accuracy: 0.8570 - val_gender_output_loss: 0.3628 - val_loss: 7.1462 - learning_rate: 0.0010
# Epoch 7/15
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - age_output_loss: 130.8257 - age_output_mae: 8.7999 - gender_output_accuracy: 0.8285 - gender_output_loss: 0.3786 - loss: 6.9164 - val_age_output_loss: 134.9408 - val_age_output_mae: 8.7844 - val_gender_output_accuracy: 0.8540 - val_gender_output_loss: 0.3413 - val_loss: 7.0819 - learning_rate: 0.0010
# Epoch 8/15
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - age_output_loss: 128.5675 - age_output_mae: 8.7216 - gender_output_accuracy: 0.8297 - gender_output_loss: 0.3813 - loss: 6.8080 - val_age_output_loss: 137.3001 - val_age_output_mae: 8.8473 - val_gender_output_accuracy: 0.8564 - val_gender_output_loss: 0.3561 - val_loss: 7.2166 - learning_rate: 0.0010
# Epoch 9/15
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - age_output_loss: 128.3976 - age_output_mae: 8.7195 - gender_output_accuracy: 0.8341 - gender_output_loss: 0.3764 - loss: 6.7932 - val_age_output_loss: 133.5574 - val_age_output_mae: 8.7801 - val_gender_output_accuracy: 0.8587 - val_gender_output_loss: 0.3443 - val_loss: 7.0189 - learning_rate: 0.0010
# Epoch 10/15
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 21s 43ms/step - age_output_loss: 126.3446 - age_output_mae: 8.6269 - gender_output_accuracy: 0.8252 - gender_output_loss: 0.3872 - loss: 6.7050 - val_age_output_loss: 134.8524 - val_age_output_mae: 8.8404 - val_gender_output_accuracy: 0.8481 - val_gender_output_loss: 0.3310 - val_loss: 7.0710 - learning_rate: 0.0010
# Epoch 11/15
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 15s 40ms/step - age_output_loss: 126.5027 - age_output_mae: 8.6437 - gender_output_accuracy: 0.8273 - gender_output_loss: 0.3824 - loss: 6.7071 - val_age_output_loss: 132.6409 - val_age_output_mae: 8.7548 - val_gender_output_accuracy: 0.8487 - val_gender_output_loss: 0.3303 - val_loss: 6.9578 - learning_rate: 0.0010
# Epoch 12/15
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - age_output_loss: 125.8755 - age_output_mae: 8.6613 - gender_output_accuracy: 0.8298 - gender_output_loss: 0.3892 - loss: 6.6809 - val_age_output_loss: 131.9167 - val_age_output_mae: 8.7560 - val_gender_output_accuracy: 0.8564 - val_gender_output_loss: 0.3402 - val_loss: 6.9346 - learning_rate: 0.0010
# Epoch 13/15
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 16s 40ms/step - age_output_loss: 123.2210 - age_output_mae: 8.5738 - gender_output_accuracy: 0.8289 - gender_output_loss: 0.3846 - loss: 6.5432 - val_age_output_loss: 132.0236 - val_age_output_mae: 8.7195 - val_gender_output_accuracy: 0.8582 - val_gender_output_loss: 0.3360 - val_loss: 6.9323 - learning_rate: 0.0010
# Epoch 14/15
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 16s 40ms/step - age_output_loss: 124.6330 - age_output_mae: 8.6122 - gender_output_accuracy: 0.8302 - gender_output_loss: 0.3824 - loss: 6.6097 - val_age_output_loss: 133.6517 - val_age_output_mae: 8.8494 - val_gender_output_accuracy: 0.8440 - val_gender_output_loss: 0.3393 - val_loss: 7.0195 - learning_rate: 0.0010
# Epoch 15/15
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - age_output_loss: 123.4356 - age_output_mae: 8.5727 - gender_output_accuracy: 0.8285 - gender_output_loss: 0.3886 - loss: 6.5551 - val_age_output_loss: 130.4280 - val_age_output_mae: 8.6886 - val_gender_output_accuracy: 0.8534 - val_gender_output_loss: 0.3376 - val_loss: 6.8583 - learning_rate: 0.0010

# %%
base_model.trainable = True
for layer in base_model.layers[:-30]:
    layer.trainable = False

model.compile(
    optimizer=Adam(1e-5),  # must be low — protects pretrained weights
    loss={'age_output': 'mse', 'gender_output': 'binary_crossentropy'},
    loss_weights={'age_output': 0.05, 'gender_output': 1.0},
    metrics={'age_output': 'mae', 'gender_output': 'accuracy'}
)

history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=[
        EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3),
        ModelCheckpoint('best_model.keras', save_best_only=True, monitor='val_loss')
    ]
)
# Out:
# Epoch 1/30
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 54s 90ms/step - age_output_loss: 215.3442 - age_output_mae: 11.2169 - gender_output_accuracy: 0.7141 - gender_output_loss: 0.6171 - loss: 11.3827 - val_age_output_loss: 209.1365 - val_age_output_mae: 10.6885 - val_gender_output_accuracy: 0.8280 - val_gender_output_loss: 0.4304 - val_loss: 10.8985 - learning_rate: 1.0000e-05
# Epoch 2/30
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 18s 46ms/step - age_output_loss: 159.2668 - age_output_mae: 9.6772 - gender_output_accuracy: 0.7343 - gender_output_loss: 0.5745 - loss: 8.5347 - val_age_output_loss: 258.5504 - val_age_output_mae: 10.8131 - val_gender_output_accuracy: 0.8109 - val_gender_output_loss: 0.4653 - val_loss: 13.4083 - learning_rate: 1.0000e-05
# Epoch 3/30
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - age_output_loss: 138.7587 - age_output_mae: 9.0811 - gender_output_accuracy: 0.7519 - gender_output_loss: 0.5364 - loss: 7.4696 - val_age_output_loss: 180.6528 - val_age_output_mae: 9.4599 - val_gender_output_accuracy: 0.8008 - val_gender_output_loss: 0.4324 - val_loss: 9.4699 - learning_rate: 1.0000e-05
# Epoch 4/30
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 20s 48ms/step - age_output_loss: 121.9589 - age_output_mae: 8.5290 - gender_output_accuracy: 0.7609 - gender_output_loss: 0.5214 - loss: 6.6160 - val_age_output_loss: 152.1612 - val_age_output_mae: 8.9529 - val_gender_output_accuracy: 0.8126 - val_gender_output_loss: 0.4291 - val_loss: 8.0386 - learning_rate: 1.0000e-05
# Epoch 5/30
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 19s 48ms/step - age_output_loss: 112.9051 - age_output_mae: 8.2063 - gender_output_accuracy: 0.7640 - gender_output_loss: 0.5087 - loss: 6.1526 - val_age_output_loss: 146.1890 - val_age_output_mae: 8.6701 - val_gender_output_accuracy: 0.8138 - val_gender_output_loss: 0.4372 - val_loss: 7.7471 - learning_rate: 1.0000e-05
# Epoch 6/30
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 19s 44ms/step - age_output_loss: 102.7815 - age_output_mae: 7.8487 - gender_output_accuracy: 0.7763 - gender_output_loss: 0.4914 - loss: 5.6269 - val_age_output_loss: 148.9932 - val_age_output_mae: 8.5272 - val_gender_output_accuracy: 0.8180 - val_gender_output_loss: 0.4322 - val_loss: 7.8827 - learning_rate: 1.0000e-05
# Epoch 7/30
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - age_output_loss: 96.8227 - age_output_mae: 7.6136 - gender_output_accuracy: 0.7760 - gender_output_loss: 0.4842 - loss: 5.3215 - val_age_output_loss: 142.0844 - val_age_output_mae: 8.3957 - val_gender_output_accuracy: 0.8162 - val_gender_output_loss: 0.4274 - val_loss: 7.5316 - learning_rate: 1.0000e-05
# Epoch 8/30
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 20s 46ms/step - age_output_loss: 88.9067 - age_output_mae: 7.3240 - gender_output_accuracy: 0.7865 - gender_output_loss: 0.4698 - loss: 4.9127 - val_age_output_loss: 134.9527 - val_age_output_mae: 8.3575 - val_gender_output_accuracy: 0.8186 - val_gender_output_loss: 0.4311 - val_loss: 7.1797 - learning_rate: 1.0000e-05
# Epoch 9/30
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 17s 45ms/step - age_output_loss: 84.0240 - age_output_mae: 7.1058 - gender_output_accuracy: 0.7877 - gender_output_loss: 0.4615 - loss: 4.6601 - val_age_output_loss: 140.1131 - val_age_output_mae: 8.2594 - val_gender_output_accuracy: 0.8186 - val_gender_output_loss: 0.4265 - val_loss: 7.4335 - learning_rate: 1.0000e-05
# Epoch 10/30
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 21s 47ms/step - age_output_loss: 77.0449 - age_output_mae: 6.8065 - gender_output_accuracy: 0.7961 - gender_output_loss: 0.4460 - loss: 4.2956 - val_age_output_loss: 149.9832 - val_age_output_mae: 8.2592 - val_gender_output_accuracy: 0.8168 - val_gender_output_loss: 0.4160 - val_loss: 7.9176 - learning_rate: 1.0000e-05
# Epoch 11/30
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 18s 47ms/step - age_output_loss: 71.9863 - age_output_mae: 6.5887 - gender_output_accuracy: 0.7953 - gender_output_loss: 0.4467 - loss: 4.0425 - val_age_output_loss: 144.1903 - val_age_output_mae: 8.2329 - val_gender_output_accuracy: 0.8180 - val_gender_output_loss: 0.4143 - val_loss: 7.6253 - learning_rate: 1.0000e-05
# Epoch 12/30
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 17s 45ms/step - age_output_loss: 67.1635 - age_output_mae: 6.3637 - gender_output_accuracy: 0.7983 - gender_output_loss: 0.4393 - loss: 3.7937 - val_age_output_loss: 143.8727 - val_age_output_mae: 8.2194 - val_gender_output_accuracy: 0.8209 - val_gender_output_loss: 0.4105 - val_loss: 7.6056 - learning_rate: 3.0000e-06
# Epoch 13/30
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 17s 44ms/step - age_output_loss: 65.1246 - age_output_mae: 6.2674 - gender_output_accuracy: 0.8001 - gender_output_loss: 0.4426 - loss: 3.6967 - val_age_output_loss: 142.0441 - val_age_output_mae: 8.2361 - val_gender_output_accuracy: 0.8209 - val_gender_output_loss: 0.4090 - val_loss: 7.5128 - learning_rate: 3.0000e-06
# Epoch 14/30
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 18s 47ms/step - age_output_loss: 65.3709 - age_output_mae: 6.3003 - gender_output_accuracy: 0.7977 - gender_output_loss: 0.4339 - loss: 3.7015 - val_age_output_loss: 136.1514 - val_age_output_mae: 8.2074 - val_gender_output_accuracy: 0.8197 - val_gender_output_loss: 0.4061 - val_loss: 7.2146 - learning_rate: 3.0000e-06

# %%
def plot_history(h1, h2, metric, title, ylabel):
    full_train = h1.history[metric] + h2.history[metric]
    full_val   = h1.history[f'val_{metric}'] + h2.history[f'val_{metric}']
    split_pt   = len(h1.history[metric])

    plt.plot(full_train, label='Train')
    plt.plot(full_val,   label='Validation')
    plt.axvline(split_pt, color='gray', linestyle='--', label='Fine-tune start')
    plt.title(title); plt.xlabel('Epoch'); plt.ylabel(ylabel); plt.legend()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plot_history(history1, history2, 'age_output_mae', 'Age MAE', 'MAE (years)')
plt.subplot(1, 2, 2)
plot_history(history1, history2, 'gender_output_accuracy', 'Gender Accuracy', 'Accuracy')
plt.tight_layout(); plt.show()

# %%
model = tf.keras.models.load_model('best_model.keras')  # load the best checkpoint

results = model.evaluate(test_ds, verbose=1)
print(f"\nTest Age MAE     : {results[3]:.2f} years")
print(f"Test Gender Acc  : {results[4]*100:.1f}%")
# Out:
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 19s 177ms/step - age_output_loss: 119.9949 - age_output_mae: 8.2376 - gender_output_accuracy: 0.8114 - gender_output_loss: 0.4217 - loss: 6.4219
#
# Test Age MAE     : 8.24 years
# Test Gender Acc  : 81.1%

# %%
from google.colab import files
files.download('best_model.keras')

# %%
def make_gradcam_heatmap(img_array, model, last_conv_layer_name='Conv_1'):
    # Model that outputs last conv layer + final predictions
    grad_model = Model(
        inputs=model.inputs,
        outputs=[
            model.get_layer(last_conv_layer_name).output,
            model.output
        ]
    )
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        # Use age output as the target for Grad-CAM
        loss = predictions[0][:, 0]

    grads      = tape.gradient(loss, conv_outputs)
    pooled     = tf.reduce_mean(grads, axis=(0, 1, 2))
    conv_out   = conv_outputs[0]
    heatmap    = conv_out @ pooled[..., tf.newaxis]
    heatmap    = tf.squeeze(heatmap)
    heatmap    = tf.maximum(heatmap, 0) / (tf.math.reduce_max(heatmap) + 1e-8)
    return heatmap.numpy()

def overlay_gradcam(original_img, heatmap, alpha=0.4):
    heatmap_resized = np.uint8(255 * heatmap)
    colormap  = cm.get_cmap('jet')
    colored   = colormap(
        np.uint8(255 * heatmap) / 255.0
    )[:, :, :3]
    colored   = np.uint8(colored * 255)
    colored   = Image.fromarray(colored).resize(
        (original_img.shape[1], original_img.shape[0])
    )
    colored   = np.array(colored)
    overlay   = np.uint8(original_img * (1 - alpha) + colored * alpha)
    return overlay

# %%
import gradio as gr
import matplotlib.cm as cm
from PIL import Image

GENDER_LABELS = {0: 'Male', 1: 'Female'}

def predict(image):
    # Preprocess
    img_resized = image.resize((IMG_SIZE, IMG_SIZE))
    img_array   = np.array(img_resized).astype(np.float32) / 255.0
    img_input   = np.expand_dims(img_array, axis=0)

    # Predict
    age_pred, gender_pred = model.predict(img_input, verbose=0)
    age    = int(np.round(age_pred[0][0]))
    gender = GENDER_LABELS[int(gender_pred[0][0] >= 0.5)]
    confidence = float(gender_pred[0][0]) if gender == 'Female' else 1 - float(gender_pred[0][0])

    # Grad-CAM
    heatmap = make_gradcam_heatmap(img_input, model)
    gradcam = overlay_gradcam(np.array(img_resized), heatmap)

    result_text = f"Predicted Age: {age} years\nGender: {gender} ({confidence*100:.1f}% confidence)"
    return result_text, Image.fromarray(gradcam)

demo = gr.Interface(
    fn=predict,
    inputs=gr.Image(type='pil', label="Upload a face photo"),
    outputs=[
        gr.Textbox(label="Prediction"),
        gr.Image(label="Grad-CAM Heatmap")
    ],
    title="Age & Gender Predictor",
    description="Upload a face image to predict age and gender. The heatmap shows which facial regions the model focused on.",
    examples=[]  # optionally add example images here
)

demo.launch(share=True)  # share=True gives you a public URL from Colab
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://9e329fc8e98d823682.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9e329fc8e98d823682.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
